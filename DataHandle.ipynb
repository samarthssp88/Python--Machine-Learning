# %% [markdown]
# 🔴Data Handling

# %% [markdown]
# 🔴Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# 🔴Importing Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_excel("/content/drive/My Drive/Colab Notebooks/AssgnBook1.xlsx")
df
# Out:
#     CustomerId  StreetNo          Streetname OwnerOccupied  NoBedRooms  \
# 0          234     104.0             MG Road             Y         3.0
# 1          344     197.0        Shivaji Road             N         3.0
# 2          245       NaN  Netaji Subash Road             N         NaN
# 3          523     201.0        Shivaji Road            12         1.0
# 4          123     203.0           Azad Road             Y         3.0
# 5          235    2007.0           Azad Road             Y         NaN
# 6          255       NaN        Pragati Marg           NaN         2.0
# 7          367     213.0         Gole Market             Y         1.0
# 8          347     215.0         Gole Market             Y         NaN
# 9          523     201.0        Shivaji Road            12         1.0
# 10         255       NaN        Pragati Marg           NaN         2.0
#
#    NoBathRooms AreaSqFt  Color
# 0            1     1000  White
# 1          1.5       __    Red
# ...

# %%
df.head()
# Out:
#    CustomerId  StreetNo          Streetname OwnerOccupied  NoBedRooms  \
# 0         234     104.0             MG Road             Y         3.0
# 1         344     197.0        Shivaji Road             N         3.0
# 2         245       NaN  Netaji Subash Road             N         NaN
# 3         523     201.0        Shivaji Road            12         1.0
# 4         123     203.0           Azad Road             Y         3.0
#
#   NoBathRooms AreaSqFt  Color
# 0           1     1000  White
# 1         1.5       __    Red
# 2           1      850   Pink
# 3         NAN      700  Yello
# 4           2     1600  Green

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustomerId     11 non-null     int64
#  1   StreetNo       8 non-null      float64
#  2   Streetname     11 non-null     object
#  3   OwnerOccupied  9 non-null      object
#  4   NoBedRooms     8 non-null      float64
#  5   NoBathRooms    11 non-null     object
#  6   AreaSqFt       10 non-null     object
#  7   Color          11 non-null     object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 832.0+ bytes

# %%
df.columns
# Out:
# Index(['CustomerId', 'StreetNo', 'Streetname', 'OwnerOccupied', 'NoBedRooms',
#        'NoBathRooms', 'AreaSqFt', 'Color'],
#       dtype='object')

# %%
df.describe()
# Out:
#        CustomerId     StreetNo  NoBedRooms
# count   11.000000     8.000000     8.00000
# mean   313.727273   417.625000     2.00000
# std    123.694859   643.205574     0.92582
# min    123.000000   104.000000     1.00000
# 25%    240.000000   200.000000     1.00000
# 50%    255.000000   202.000000     2.00000
# 75%    357.000000   213.500000     3.00000
# max    523.000000  2007.000000     3.00000

# %% [markdown]
# 🔴Checking for Duplicates

# %%
#6. Count number of duplicate rows and remove them.
df.duplicated().sum()
# Out:
# 2

# %% [markdown]
# 🔴Removing duplicates

# %%
df.drop_duplicates()
# Out:
#    CustomerId  StreetNo          Streetname OwnerOccupied  NoBedRooms  \
# 0         234     104.0             MG Road             Y         3.0
# 1         344     197.0        Shivaji Road             N         3.0
# 2         245       NaN  Netaji Subash Road             N         NaN
# 3         523     201.0        Shivaji Road            12         1.0
# 4         123     203.0           Azad Road             Y         3.0
# 5         235    2007.0           Azad Road             Y         NaN
# 6         255       NaN        Pragati Marg           NaN         2.0
# 7         367     213.0         Gole Market             Y         1.0
# 8         347     215.0         Gole Market             Y         NaN
#
#   NoBathRooms AreaSqFt  Color
# 0           1     1000  White
# 1         1.5       __    Red
# 2           1      850   Pink
# 3         NAN      700  Yello
# 4           2     1600  Green
# 5           1      800  White
# 6       Delhi      950    Red
# ...

# %%
df.shape
# Out:
# (11, 8)

# %%
#1. Count the number of missing values per column
df.isna().sum()
# Out:
# CustomerId       0
# StreetNo         3
# Streetname       0
# OwnerOccupied    2
# NoBedRooms       3
# NoBathRooms      0
# AreaSqFt         1
# Color            0
# dtype: int64

# %%
#2. Count total missing values
df.isna().sum().sum()
# Out:
# 9

# %%
#3. How many observations remain if we drop rows with missing values?
ndf=df.dropna()
ndf.shape
# Out:
# (5, 8)

# %%
#5. Rename the columen 'AreaSqFt' with "Area'
df.rename(columns={"AreaSqFt":"Area"},inplace=True)

# %%
df
# Out:
#     CustomerId  StreetNo          Streetname OwnerOccupied  NoBedRooms  \
# 0          234     104.0             MG Road             Y         3.0
# 1          344     197.0        Shivaji Road             N         3.0
# 2          245       NaN  Netaji Subash Road             N         NaN
# 3          523     201.0        Shivaji Road            12         1.0
# 4          123     203.0           Azad Road             Y         3.0
# 5          235    2007.0           Azad Road             Y         NaN
# 6          255       NaN        Pragati Marg           NaN         2.0
# 7          367     213.0         Gole Market             Y         1.0
# 8          347     215.0         Gole Market             Y         NaN
# 9          523     201.0        Shivaji Road            12         1.0
# 10         255       NaN        Pragati Marg           NaN         2.0
#
#    NoBathRooms  Area  Color
# 0            1  1000  White
# 1          1.5    __    Red
# ...

# %%
#7. Remove column 'color'
df.drop('Color',axis=1)
# Out:
#     CustomerId  StreetNo          Streetname OwnerOccupied  NoBedRooms  \
# 0          234     104.0             MG Road             Y         3.0
# 1          344     197.0        Shivaji Road             N         3.0
# 2          245       NaN  Netaji Subash Road             N         NaN
# 3          523     201.0        Shivaji Road            12         1.0
# 4          123     203.0           Azad Road             Y         3.0
# 5          235    2007.0           Azad Road             Y         NaN
# 6          255       NaN        Pragati Marg           NaN         2.0
# 7          367     213.0         Gole Market             Y         1.0
# 8          347     215.0         Gole Market             Y         NaN
# 9          523     201.0        Shivaji Road            12         1.0
# 10         255       NaN        Pragati Marg           NaN         2.0
#
#    NoBathRooms  Area
# 0            1  1000
# 1          1.5    __
# 2            1   850
# 3          NAN   700
# ...

# %%
#8. Make CustomerId column index
df.set_index("CustomerId")
# Out:
#             StreetNo          Streetname OwnerOccupied  NoBedRooms  \
# CustomerId
# 234            104.0             MG Road             Y         3.0
# 344            197.0        Shivaji Road             N         3.0
# 245              NaN  Netaji Subash Road             N         NaN
# 523            201.0        Shivaji Road            12         1.0
# 123            203.0           Azad Road             Y         3.0
# 235           2007.0           Azad Road             Y         NaN
# 255              NaN        Pragati Marg           NaN         2.0
# 367            213.0         Gole Market             Y         1.0
# 347            215.0         Gole Market             Y         NaN
# 523            201.0        Shivaji Road            12         1.0
# 255              NaN        Pragati Marg           NaN         2.0
#
#            NoBathRooms  Area  Color
# CustomerId
# 234                  1  1000  White
# 344                1.5    __    Red
# ...

# %%
#9. In the “OwnerOccupied” column, ensure that there are no numeric values.
for i in df.OwnerOccupied:
  if str(i).isdigit():
    df.replace({i:np.NaN},inplace=True)

# %%
df
# Out:
#     CustomerId  StreetNo          Streetname OwnerOccupied  NoBedRooms  \
# 0          234     104.0             MG Road             Y         3.0
# 1          344     197.0        Shivaji Road             N         3.0
# 2          245       NaN  Netaji Subash Road             N         NaN
# 3          523     201.0        Shivaji Road           NaN         1.0
# 4          123     203.0           Azad Road             Y         3.0
# 5          235    2007.0           Azad Road             Y         NaN
# 6          255       NaN        Pragati Marg           NaN         2.0
# 7          367     213.0         Gole Market             Y         1.0
# 8          347     215.0         Gole Market             Y         NaN
# 9          523     201.0        Shivaji Road           NaN         1.0
# 10         255       NaN        Pragati Marg           NaN         2.0
#
#    NoBathRooms  Area  Color
# 0            1  1000  White
# 1          1.5    __    Red
# ...

# %%
#10. For customer id=245, fill the “Streetno” with value “125”
df.loc[2,"StreetNo"]=125

# %%
df[df["CustomerId"]==245]
# Out:
#    CustomerId  StreetNo          Streetname OwnerOccupied  NoBedRooms  \
# 2         245     125.0  Netaji Subash Road             N         NaN
#
#   NoBathRooms Area Color
# 2           1  850  Pink

# %%
#11. Fill the “NoBedRooms” with median value of the column
df.fillna(df['NoBedRooms'].median(), inplace = True)
df
# Out:
#     CustomerId  StreetNo          Streetname OwnerOccupied  NoBedRooms  \
# 0          234     104.0             MG Road             Y         3.0
# 1          344     197.0        Shivaji Road             N         3.0
# 2          245     125.0  Netaji Subash Road             N         2.0
# 3          523     201.0        Shivaji Road           2.0         1.0
# 4          123     203.0           Azad Road             Y         3.0
# 5          235    2007.0           Azad Road             Y         2.0
# 6          255       2.0        Pragati Marg           2.0         2.0
# 7          367     213.0         Gole Market             Y         1.0
# 8          347     215.0         Gole Market             Y         2.0
# 9          523     201.0        Shivaji Road           2.0         1.0
# 10         255       2.0        Pragati Marg           2.0         2.0
#
#    NoBathRooms  Area  Color
# 0            1  1000  White
# 1          1.5    __    Red
# ...
