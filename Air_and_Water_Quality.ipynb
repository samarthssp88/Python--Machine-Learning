# %% [markdown]
# 🔴Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests

# %% [markdown]
# 🔴Importing Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_excel("/content/drive/My Drive/Colab Notebooks/cities_air_quality_water_pollution.xlsx")

# %%
df.head()
# Out:
#                City                Region                   Country  \
# 0     New York City              New York  United States of America
# 1  Washington, D.C.  District of Columbia  United States of America
# 2     San Francisco            California  United States of America
# 3            Berlin                   NaN                   Germany
# 4       Los Angeles            California  United States of America
#
#    AirQuality  WaterPollution
# 0   46.816038       49.504950
# 1   66.129032       49.107143
# 2   60.514019       43.000000
# 3   62.364130       28.612717
# 4   36.621622       61.299435

# %%
df.describe()
# Out:
#         AirQuality  WaterPollution
# count  3963.000000     3963.000000
# mean     62.253452       44.635372
# std      30.944753       25.663910
# min       0.000000        0.000000
# 25%      37.686567       25.000000
# 50%      69.444444       50.000000
# 75%      87.500000       57.719393
# max     100.000000      100.000000

# %% [markdown]
# 🔴Which cities have the highest and lowest air quality?

# %%
highest_AQ_city = df.loc[df['AirQuality'].idxmax(), 'City']
lowest_AQ_city = df.loc[df['AirQuality'].idxmin(), 'City']
print("City with the highest AirQuality:", highest_AQ_city)
print("City with the lowest AirQuality:", lowest_AQ_city)
# Out:
# City with the highest AirQuality: Vaduz
# City with the lowest AirQuality: Abakan

# %% [markdown]
# 🔴Which cities have the highest and lowest water pollution levels?

# %%
highest_pollution_city = df.loc[df['WaterPollution'].idxmax(), 'City']
lowest_pollution_city = df.loc[df['WaterPollution'].idxmin(), 'City']
print("City with the highest water pollution level:", highest_pollution_city)
print("City with the lowest water pollution level:", lowest_pollution_city)
# Out:
# City with the highest water pollution level: Nowy Sacz
# City with the lowest water pollution level: Heilbronn

# %% [markdown]
# 🔴Is there any relationship between air quality and water pollution in the dataset?

# %%
correlation = df['AirQuality'].corr(df['WaterPollution'])
print("Correlation between air quality and water pollution:", correlation)
plt.figure(figsize=(8, 6))
sns.scatterplot(x='AirQuality', y='WaterPollution', data=df)
plt.xlabel('AirQuality')
plt.ylabel('WaterPollution')
plt.title('Relationship between Air Quality and Water Pollution')
plt.show()
# Out:
# Correlation between air quality and water pollution: -0.45417262259278224
